# %% [markdown]
# | 파트          | 내용                                           |
# | ----------- | -------------------------------------------- |
# | **데이터 전처리** | MNIST 손글씨 이미지(28×28)를 1차원으로 펴고 정규화 + 원-핫 인코딩 |
# | **모델 구성**   | 입력층(784) → 은닉층(512, tanh) → 출력층(10, softmax) |
# | **컴파일**     | 손실함수 MSE, Adam 옵티마이저, 정확도 측정                 |
# | **학습**      | 50 에포크 동안 배치 크기 128로 학습                      |
# | **평가**      | 테스트셋 정확도 출력                                  |

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

# Keras의 주요 구성요소 모듈 불러오기
from tensorflow.keras.models import Sequential      # 순차 모델
from tensorflow.keras.layers import Dense           # 완전 연결(Dense) 층
from tensorflow.keras.optimizers import Adam        # Adam 옵티마이저

# ----------------------------------------
# [1] 데이터셋 로드 및 전처리
# ----------------------------------------

# MNIST 데이터셋 불러오기: (훈련 데이터, 테스트 데이터)
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()

# 입력 데이터를 1차원 벡터로 변환 (28x28 이미지를 784차원 벡터로)
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

# 입력 데이터 정규화: 0~255 범위를 0~1로 변환 (float32 타입)
x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0

# 출력 데이터를 원-핫 인코딩으로 변환 (10개의 숫자 클래스)
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# ----------------------------------------
# [2] MLP 모델 구성
# ----------------------------------------

mlp = Sequential()  # 순차적 모델 정의

# 첫 번째 Dense 층: 입력 784 → 출력 512, 활성 함수는 tanh
mlp.add(Dense(units=512, activation='tanh', input_shape=(784,)))

# 출력층: 클래스 개수 10개, softmax로 확률 출력
mlp.add(Dense(units=10, activation='softmax'))

# ----------------------------------------
# [3] 모델 컴파일
# ----------------------------------------

# 손실함수: MSE (평균 제곱 오차)
# 옵티마이저: Adam (학습률 0.001)
# 평가지표: accuracy
mlp.compile(loss='MSE', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# ----------------------------------------
# [4] 모델 학습
# ----------------------------------------

# 배치 크기: 128개씩
# 에포크 수: 50번 반복 학습
# 검증 데이터: 테스트셋 사용
# verbose=2: 에포크별 진행상황 출력
mlp.fit(x_train, y_train, batch_size=128, epochs=50, validation_data=(x_test, y_test), verbose=2)

# ----------------------------------------
# [5] 최종 평가
# ----------------------------------------

# 테스트셋으로 평가하고 정확도 출력
res = mlp.evaluate(x_test, y_test, verbose=0)
print('정확률 =', res[1] * 100)
# Out:
# Epoch 1/50
# 469/469 - 2s - loss: 0.0149 - accuracy: 0.9002 - val_loss: 0.0103 - val_accuracy: 0.9326 - 2s/epoch - 4ms/step
# Epoch 2/50
# 469/469 - 1s - loss: 0.0090 - accuracy: 0.9419 - val_loss: 0.0078 - val_accuracy: 0.9487 - 537ms/epoch - 1ms/step
# Epoch 3/50
# 469/469 - 1s - loss: 0.0065 - accuracy: 0.9583 - val_loss: 0.0059 - val_accuracy: 0.9621 - 515ms/epoch - 1ms/step
# Epoch 4/50
# 469/469 - 1s - loss: 0.0050 - accuracy: 0.9688 - val_loss: 0.0055 - val_accuracy: 0.9638 - 517ms/epoch - 1ms/step
# Epoch 5/50
# 469/469 - 1s - loss: 0.0040 - accuracy: 0.9756 - val_loss: 0.0043 - val_accuracy: 0.9725 - 518ms/epoch - 1ms/step
# Epoch 6/50
# 469/469 - 1s - loss: 0.0033 - accuracy: 0.9799 - val_loss: 0.0042 - val_accuracy: 0.9729 - 514ms/epoch - 1ms/step
# Epoch 7/50
# 469/469 - 1s - loss: 0.0028 - accuracy: 0.9837 - val_loss: 0.0042 - val_accuracy: 0.9726 - 520ms/epoch - 1ms/step
# Epoch 8/50
# 469/469 - 1s - loss: 0.0023 - accuracy: 0.9865 - val_loss: 0.0038 - val_accuracy: 0.9756 - 527ms/epoch - 1ms/step
# Epoch 9/50
# 469/469 - 1s - loss: 0.0021 - accuracy: 0.9884 - val_loss: 0.0034 - val_accuracy: 0.9773 - 541ms/epoch - 1ms/step
# Epoch 10/50
# 469/469 - 1s - loss: 0.0017 - accuracy: 0.9904 - val_loss: 0.0032 - val_accuracy: 0.9792 - 547ms/epoch - 1ms/step
# Epoch 11/50
# 469/469 - 1s - loss: 0.0015 - accuracy: 0.9919 - val_loss: 0.0035 - val_accuracy: 0.9768 - 565ms/epoch - 1ms/step
# Epoch 12/50
# 469/469 - 1s - loss: 0.0013 - accuracy: 0.9930 - val_loss: 0.0033 - val_accuracy: 0.9772 - 565ms/epoch - 1ms/step
# Epoch 13/50
# 469/469 - 1s - loss: 0.0011 - accuracy: 0.9944 - val_loss: 0.0032 - val_accuracy: 0.9783 - 566ms/epoch - 1ms/step
# Epoch 14/50
# 469/469 - 1s - loss: 9.1914e-04 - accuracy: 0.9950 - val_loss: 0.0032 - val_accuracy: 0.9790 - 570ms/epoch - 1ms/step
# Epoch 15/50
# 469/469 - 1s - loss: 8.3184e-04 - accuracy: 0.9956 - val_loss: 0.0034 - val_accuracy: 0.9777 - 571ms/epoch - 1ms/step
# Epoch 16/50
# 469/469 - 1s - loss: 6.7083e-04 - accuracy: 0.9967 - val_loss: 0.0029 - val_accuracy: 0.9809 - 579ms/epoch - 1ms/step
# Epoch 17/50
# 469/469 - 1s - loss: 5.3427e-04 - accuracy: 0.9975 - val_loss: 0.0029 - val_accuracy: 0.9805 - 573ms/epoch - 1ms/step
# Epoch 18/50
# 469/469 - 1s - loss: 6.0344e-04 - accuracy: 0.9969 - val_loss: 0.0031 - val_accuracy: 0.9799 - 582ms/epoch - 1ms/step
# Epoch 19/50
# 469/469 - 1s - loss: 4.5605e-04 - accuracy: 0.9978 - val_loss: 0.0028 - val_accuracy: 0.9816 - 571ms/epoch - 1ms/step
# Epoch 20/50
# 469/469 - 1s - loss: 4.6422e-04 - accuracy: 0.9977 - val_loss: 0.0031 - val_accuracy: 0.9800 - 570ms/epoch - 1ms/step
# Epoch 21/50
# 469/469 - 1s - loss: 4.2401e-04 - accuracy: 0.9979 - val_loss: 0.0029 - val_accuracy: 0.9811 - 595ms/epoch - 1ms/step
# Epoch 22/50
# 469/469 - 1s - loss: 4.6337e-04 - accuracy: 0.9976 - val_loss: 0.0031 - val_accuracy: 0.9796 - 607ms/epoch - 1ms/step
# Epoch 23/50
# 469/469 - 1s - loss: 4.1634e-04 - accuracy: 0.9978 - val_loss: 0.0032 - val_accuracy: 0.9801 - 587ms/epoch - 1ms/step
# Epoch 24/50
# 469/469 - 1s - loss: 3.8323e-04 - accuracy: 0.9980 - val_loss: 0.0031 - val_accuracy: 0.9796 - 581ms/epoch - 1ms/step
# Epoch 25/50
# 469/469 - 1s - loss: 3.8589e-04 - accuracy: 0.9980 - val_loss: 0.0036 - val_accuracy: 0.9766 - 574ms/epoch - 1ms/step
# Epoch 26/50
# 469/469 - 1s - loss: 2.9869e-04 - accuracy: 0.9985 - val_loss: 0.0029 - val_accuracy: 0.9812 - 636ms/epoch - 1ms/step
# Epoch 27/50
# 469/469 - 1s - loss: 3.1633e-04 - accuracy: 0.9983 - val_loss: 0.0033 - val_accuracy: 0.9789 - 577ms/epoch - 1ms/step
# Epoch 28/50
# 469/469 - 1s - loss: 4.4201e-04 - accuracy: 0.9975 - val_loss: 0.0030 - val_accuracy: 0.9812 - 606ms/epoch - 1ms/step
# Epoch 29/50
# 469/469 - 1s - loss: 3.4479e-04 - accuracy: 0.9982 - val_loss: 0.0029 - val_accuracy: 0.9814 - 618ms/epoch - 1ms/step
# Epoch 30/50
# 469/469 - 1s - loss: 3.1248e-04 - accuracy: 0.9984 - val_loss: 0.0029 - val_accuracy: 0.9814 - 541ms/epoch - 1ms/step
# Epoch 31/50
# 469/469 - 1s - loss: 2.7814e-04 - accuracy: 0.9985 - val_loss: 0.0030 - val_accuracy: 0.9818 - 579ms/epoch - 1ms/step
# Epoch 32/50
# 469/469 - 1s - loss: 2.4085e-04 - accuracy: 0.9988 - val_loss: 0.0031 - val_accuracy: 0.9813 - 581ms/epoch - 1ms/step
# Epoch 33/50
# 469/469 - 1s - loss: 2.3472e-04 - accuracy: 0.9987 - val_loss: 0.0030 - val_accuracy: 0.9813 - 561ms/epoch - 1ms/step
# Epoch 34/50
# 469/469 - 1s - loss: 4.0244e-04 - accuracy: 0.9978 - val_loss: 0.0030 - val_accuracy: 0.9800 - 560ms/epoch - 1ms/step
# Epoch 35/50
# 469/469 - 1s - loss: 2.6759e-04 - accuracy: 0.9985 - val_loss: 0.0031 - val_accuracy: 0.9816 - 558ms/epoch - 1ms/step
# Epoch 36/50
# 469/469 - 1s - loss: 2.9993e-04 - accuracy: 0.9984 - val_loss: 0.0030 - val_accuracy: 0.9817 - 566ms/epoch - 1ms/step
# Epoch 37/50
# 469/469 - 1s - loss: 2.6076e-04 - accuracy: 0.9987 - val_loss: 0.0034 - val_accuracy: 0.9791 - 569ms/epoch - 1ms/step
# Epoch 38/50
# 469/469 - 1s - loss: 2.7690e-04 - accuracy: 0.9985 - val_loss: 0.0035 - val_accuracy: 0.9784 - 572ms/epoch - 1ms/step
# Epoch 39/50
# 469/469 - 1s - loss: 2.2417e-04 - accuracy: 0.9988 - val_loss: 0.0030 - val_accuracy: 0.9807 - 572ms/epoch - 1ms/step
# Epoch 40/50
# 469/469 - 1s - loss: 2.3566e-04 - accuracy: 0.9987 - val_loss: 0.0031 - val_accuracy: 0.9807 - 575ms/epoch - 1ms/step
# Epoch 41/50
# 469/469 - 1s - loss: 2.7167e-04 - accuracy: 0.9985 - val_loss: 0.0030 - val_accuracy: 0.9820 - 619ms/epoch - 1ms/step
# Epoch 42/50
# 469/469 - 1s - loss: 2.4612e-04 - accuracy: 0.9986 - val_loss: 0.0031 - val_accuracy: 0.9805 - 700ms/epoch - 1ms/step
# Epoch 43/50
# 469/469 - 1s - loss: 2.7327e-04 - accuracy: 0.9985 - val_loss: 0.0030 - val_accuracy: 0.9817 - 559ms/epoch - 1ms/step
# Epoch 44/50
# 469/469 - 1s - loss: 2.7125e-04 - accuracy: 0.9985 - val_loss: 0.0031 - val_accuracy: 0.9809 - 564ms/epoch - 1ms/step
# Epoch 45/50
# 469/469 - 1s - loss: 2.4664e-04 - accuracy: 0.9986 - val_loss: 0.0029 - val_accuracy: 0.9823 - 562ms/epoch - 1ms/step
# Epoch 46/50
# 469/469 - 1s - loss: 1.7799e-04 - accuracy: 0.9991 - val_loss: 0.0031 - val_accuracy: 0.9813 - 570ms/epoch - 1ms/step
# Epoch 47/50
# 469/469 - 1s - loss: 2.1037e-04 - accuracy: 0.9989 - val_loss: 0.0032 - val_accuracy: 0.9807 - 564ms/epoch - 1ms/step
# Epoch 48/50
# 469/469 - 1s - loss: 3.4752e-04 - accuracy: 0.9979 - val_loss: 0.0033 - val_accuracy: 0.9796 - 567ms/epoch - 1ms/step
# Epoch 49/50
# 469/469 - 1s - loss: 2.2350e-04 - accuracy: 0.9988 - val_loss: 0.0029 - val_accuracy: 0.9816 - 568ms/epoch - 1ms/step
# Epoch 50/50
# 469/469 - 1s - loss: 2.6684e-04 - accuracy: 0.9984 - val_loss: 0.0034 - val_accuracy: 0.9783 - 565ms/epoch - 1ms/step
# 정확률 = 97.82999753952026

# %%
import torch
print(torch.cuda.is_available())  # True면 GPU 인식 OK
print(torch.cuda.get_device_name(0))  # GPU 이름 확인
# Out:
# True
# NVIDIA GeForce RTX 4070

# %%
import tensorflow as tf
print("TF version:", tf.__version__)
print("Available GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# TF version: 2.10.0
# Available GPUs: []

# %%
import tensorflow as tf

print("✔️ TensorFlow version:", tf.__version__)
print("✔️ GPU device list:", tf.config.list_physical_devices('GPU'))

if tf.config.list_physical_devices('GPU'):
    print("✅ GPU가 정상적으로 연결되어 있습니다!")
else:
    print("❌ 현재 GPU를 찾을 수 없습니다. CPU만 사용됩니다.")
# Out:
# ✔️ TensorFlow version: 2.10.0
# ✔️ GPU device list: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# ✅ GPU가 정상적으로 연결되어 있습니다!
